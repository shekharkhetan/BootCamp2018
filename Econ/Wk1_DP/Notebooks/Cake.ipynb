# %% [markdown]
# # The Deterministic Cake Eating Problem - Value Function Iteration Solution
# ### by [Jason DeBacker](http://jasondebacker.com), June 2018
# This Jupyter notebook illustrates how to solve the deterministic cake eating problem using value function iteration (VFI).
#
#
# ## The Problem:
#
# $$V(w)=\max_{c} u(c)+\beta V(w'), \forall w\in[0,\bar{w}]$$
#
# or, substituting in the law of motion: $w' = w - c$,
#
# $$V(w)=\max_{0\leq w' \leq w}u(w-w')+\beta V(w'), \forall w$$
#
# The unknowns in this system are functions: The value function, $V(w)$, and the policy function, $c = \phi(w)$ (or, equivalently, $w' = p(w)$).
#
# ## The Solution:
#
# We'll solve this problem with value function iteration (VFI).  With this method, we'll use an iterative procedure to converge to a fixed point in function space, the true value function, $V(w)$.
#
# The computational algorithm for VFI is as follows:
#
# 1. Create a discrete grid of the state variable, $w$
# 2. Make an initial guess at the value function, $V_{0}(w)$
#     * This will be a value for each point in the state space
# 3. Perform the operation:
# $$TV(w) = \max_{w'}u(w-w') + \beta V_{0}(w')$$
# 4. Update the guess at the value function: $V_{1}(w) = TV(w)$
# 5. Repeat this process:
# $$V_{i+1} \ (w) = TV(w) = \max_{w'}u(w-w') + \beta V_{i}(w)$$
# 6. Stop when, $|V_{i+1} \ (w)-V_{i}(w)|<\varepsilon$, where $\varepsilon$ is a small number.

# %%
# Import packages
import numpy as np
import matplotlib.pyplot as plt

# to print plots inline
# %matplotlib inline

# %% [markdown]
# ## Step 1: Set parameter values
#
# Parameters:
# * $\beta$ = rate of time preference
# * $\sigma$ = coefficient of relative risk aversion (if $\sigma = 1$, $u(c)=log(c)$), parameter describes the curvature of the utility function

# %%
beta = 0.95
sigma = 1.0
R = 1

# %% [markdown]
# ## Step 2: Create Grid Space
# We will solve this model over a discrete grid.  So we'll set a grid with a finite number of pionts, each of which represent an amount of cake.
#
# We'll also want to know the flow utility from consuming each amount of cake that is possible given this grid.

# %%
'''
------------------------------------------------------------------------
Create Grid for State Space    
------------------------------------------------------------------------
lb_w      = scalar, lower bound of cake grid
ub_w      = scalar, upper bound of cake grid 
size_w    = integer, number of grid points in cake state space
w_grid    = vector, size_w x 1 vector of cake grid points 
------------------------------------------------------------------------
'''
lb_w = 0.4 
ub_w = 2.0 
size_w = 200  # Number of grid points
w_grid = np.linspace(lb_w, ub_w, size_w)

'''
------------------------------------------------------------------------
Create grid of current utility values    
------------------------------------------------------------------------
C        = matrix, current consumption (c=w-w')
U        = matrix, current period utility value for all possible
           choices of w and w' (rows are w, columns w')
------------------------------------------------------------------------
'''
C = np.zeros((size_w, size_w)) 
for i in range(size_w): # loop over w
    for j in range(size_w): # loop over w'
        C[i, j] = w_grid[i] - w_grid[j] / R # note that if w'>w, consumption negative
# replace 0 and negative consumption with a tiny value 
# This is a way to impose non-negativity on cons
C[C<=0] = 1e-15
if sigma == 1:
    U = np.log(C)
else:
    U = (C ** (1 - sigma)) / (1 - sigma)
U[C<0] = -9999999

# %% [markdown]
# ## Step 3: Value Function Iteration

# %%
'''
------------------------------------------------------------------------
Value Function Iteration    
------------------------------------------------------------------------
VFtol     = scalar, tolerance required for value function to converge
VFdist    = scalar, distance between last two value functions
VFmaxiter = integer, maximum number of iterations for value function
V         = vector, the value functions at each iteration
Vmat      = matrix, the value for each possible combination of w and w'
Vstore    = matrix, stores V at each iteration 
VFiter    = integer, current iteration number
TV        = vector, the value function after applying the Bellman operator
PF        = vector, indicies of choices of w' for all w 
VF        = vector, the "true" value function
------------------------------------------------------------------------
'''
VFtol = 1e-8 
VFdist = 7.0 
VFmaxiter = 3000 
V = np.zeros(size_w) # initial guess at value function
Vmat = np.zeros((size_w, size_w)) # initialize Vmat matrix
Vstore = np.zeros((size_w, VFmaxiter)) #initialize Vstore array
VFiter = 1 
while VFdist > VFtol and VFiter < VFmaxiter:  
    for i in range(size_w): # loop over w
        for j in range(size_w): # loop over w'
            Vmat[i, j] = U[i, j] + beta * V[j] 
      
    Vstore[:, VFiter] = V.reshape(size_w,) # store value function at each iteration for graphing later
    TV = Vmat.max(1) # apply max operator to Vmat (to get V(w))
    PF = np.argmax(Vmat, axis=1)
    VFdist = (np.absolute(V - TV)).max()  # check distance
    V = TV
    print("Iteration =", " distance = ", VFiter, VFdist )
    VFiter += 1 
    


if VFiter < VFmaxiter:
    print('Value function converged after this many iterations:', VFiter)
else:
    print('Value function did not converge')            


VF = V # solution to the functional equation
# Out:
# Iteration =  distance =  1 34.538776394910684
# Iteration =  distance =  2 29.268971751648476
# Iteration =  distance =  3 25.54610369763214
# Iteration =  distance =  4 22.48139904123985
# Iteration =  distance =  5 19.868553377835838
# Iteration =  distance =  6 17.265687796509948
# Iteration =  distance =  7 14.930791532980457
# Iteration =  distance =  8 12.8910419648447
# Iteration =  distance =  9 11.09525162619424
# Iteration =  distance =  10 9.505978447084459
# Iteration =  distance =  11 7.979638943953141
# Iteration =  distance =  12 6.555993373131415
# Iteration =  distance =  13 5.279317579229662
# Iteration =  distance =  14 4.141693330902527
# Iteration =  distance =  15 3.0453504903329502
# Iteration =  distance =  16 2.893082965816305
# Iteration =  distance =  17 2.7171505510027174
# Iteration =  distance =  18 2.5530643879157893
# Iteration =  distance =  19 2.3999348249480335
# Iteration =  distance =  20 2.2351029035569425
# Iteration =  distance =  21 2.12334775837909
# Iteration =  distance =  22 2.0085635592772846
# Iteration =  distance =  23 1.898530271052735
# Iteration =  distance =  24 1.7875473070019225
# Iteration =  distance =  25 1.696033082611656
# Iteration =  distance =  26 1.6069272965456705
# Iteration =  distance =  27 1.5195202930572052
# Iteration =  distance =  28 1.4381135382426251
# Iteration =  distance =  29 1.360154246258368
# Iteration =  distance =  30 1.2911422200316522
# Iteration =  distance =  31 1.2261215713021372
# Iteration =  distance =  32 1.1619600436721242
# Iteration =  distance =  33 1.0991778695427428
# Iteration =  distance =  34 1.0439303375945528
# Iteration =  distance =  35 0.9912697642486634
# Iteration =  distance =  36 0.9401911730806987
# Iteration =  distance =  37 0.8931816144266591
# Iteration =  distance =  38 0.8461844044201356
# Iteration =  distance =  39 0.8019377788159119
# Iteration =  distance =  40 0.7616393228656975
# Iteration =  distance =  41 0.7232332887845843
# Iteration =  distance =  42 0.6870180403364614
# Iteration =  distance =  43 0.6524919873763011
# Iteration =  distance =  44 0.6160702743593163
# Iteration =  distance =  45 0.5852667606413462
# Iteration =  distance =  46 0.5560034226092796
# Iteration =  distance =  47 0.5282032514788142
# Iteration =  distance =  48 0.5017930889048898
# Iteration =  distance =  49 0.47670343445966523
# Iteration =  distance =  50 0.4528682627366294
# Iteration =  distance =  51 0.4302248495997958
# Iteration =  distance =  52 0.4087136071198074
# Iteration =  distance =  53 0.3882779267638199
# Iteration =  distance =  54 0.36886403042562677
# Iteration =  distance =  55 0.35042082890434756
# Iteration =  distance =  56 0.33289978745912663
# Iteration =  distance =  57 0.3162547980861774
# Iteration =  distance =  58 0.3004420581818579
# Iteration =  distance =  59 0.2854199552727721
# Iteration =  distance =  60 0.2711489575091264
# Iteration =  distance =  61 0.25759150963367006
# Iteration =  distance =  62 0.24471193415197945
# Iteration =  distance =  63 0.2324763374443819
# Iteration =  distance =  64 0.22085252057216564
# Iteration =  distance =  65 0.2098098945435538
# Iteration =  distance =  66 0.1993193998163747
# Iteration =  distance =  67 0.1893534298255588
# Iteration =  distance =  68 0.17919967425221728
# Iteration =  distance =  69 0.17023969053960286
# Iteration =  distance =  70 0.16119284552620172
# Iteration =  distance =  71 0.15313320324989377
# Iteration =  distance =  72 0.14547654308739766
# Iteration =  distance =  73 0.13820271593301925
# Iteration =  distance =  74 0.13129258013637468
# Iteration =  distance =  75 0.12472795112955737
# Iteration =  distance =  76 0.1184915535730795
# Iteration =  distance =  77 0.1125669758944241
# Iteration =  distance =  78 0.10693862709970858
# Iteration =  distance =  79 0.10159169574473026
# Iteration =  distance =  80 0.0965121109574909
# Iteration =  distance =  81 0.0916865054096263
# Iteration =  distance =  82 0.08710218013912652
# Iteration =  distance =  83 0.08274707113217517
# Iteration =  distance =  84 0.07860971757556001
# Iteration =  distance =  85 0.07467923169677704
# Iteration =  distance =  86 0.07094527011194884
# Iteration =  distance =  87 0.06739800660635353
# Iteration =  distance =  88 0.06402810627604083
# Iteration =  distance =  89 0.06082670096223808
# Iteration =  distance =  90 0.057785365914128306
# Iteration =  distance =  91 0.05489609761842473
# Iteration =  distance =  92 0.05215129273750563
# Iteration =  distance =  93 0.049543728100630346
# Iteration =  distance =  94 0.04706654169559954
# Iteration =  distance =  95 0.044713214610808905
# Iteration =  distance =  96 0.042477553880274854
# Iteration =  distance =  97 0.04035367618627106
# Iteration =  distance =  98 0.038335992376957506
# Iteration =  distance =  99 0.036419192758103236
# Iteration =  distance =  100 0.0345982331202066
# Iteration =  distance =  101 0.03286832146420693
# Iteration =  distance =  102 0.031224905390999425
# Iteration =  distance =  103 0.02966366012145727
# Iteration =  distance =  104 0.028180477115384406
# Iteration =  distance =  105 0.026771453259627265
# Iteration =  distance =  106 0.025432880596653717
# Iteration =  distance =  107 0.02397674054759591
# Iteration =  distance =  108 0.0227779035202218
# Iteration =  distance =  109 0.021639008344209287
# Iteration =  distance =  110 0.02055705792700735
# Iteration =  distance =  111 0.019529205030664798
# Iteration =  distance =  112 0.018552744779128716
# Iteration =  distance =  113 0.01762510754018365
# Iteration =  distance =  114 0.016743852163187967
# Iteration =  distance =  115 0.01590665955502857
# Iteration =  distance =  116 0.015111326577269324
# Iteration =  distance =  117 0.014355760248406568
# Iteration =  distance =  118 0.013637972235983398
# Iteration =  distance =  119 0.012956073624195596
# Iteration =  distance =  120 0.012308269942991501
# Iteration =  distance =  121 0.0116928564458334
# Iteration =  distance =  122 0.011108213623543861
# Iteration =  distance =  123 0.010552802942370931
# Iteration =  distance =  124 0.01002516279525878
# Iteration =  distance =  125 0.00952390465549513
# Iteration =  distance =  126 0.009047709422716821
# Iteration =  distance =  127 0.00859532395158169
# Iteration =  distance =  128 0.008165557754011843
# Iteration =  distance =  129 0.007757279866311251
# Iteration =  distance =  130 0.007369415873000662
# Iteration =  distance =  131 0.007000945079340681
# Iteration =  distance =  132 0.006650897825380753
# Iteration =  distance =  133 0.006318352934115978
# Iteration =  distance =  134 0.006002435287413732
# Iteration =  distance =  135 0.005702313523045177
# Iteration =  distance =  136 0.0054171978468957604
# Iteration =  distance =  137 0.005146337954556657
# Iteration =  distance =  138 0.004889021056783349
# Iteration =  distance =  139 0.004644570003947024
# Iteration =  distance =  140 0.004412341503751804
# Iteration =  distance =  141 0.004191724428565635
# Iteration =  distance =  142 0.003982138207135222
# Iteration =  distance =  143 0.0037830312967912505
# Iteration =  distance =  144 0.0035938797319232663
# Iteration =  distance =  145 0.0034141857453278135
# Iteration =  distance =  146 0.003243476458067107
# Iteration =  distance =  147 0.003081302635166594
# Iteration =  distance =  148 0.0029272375034139486
# Iteration =  distance =  149 0.002780875628246804
# Iteration =  distance =  150 0.0026418318468302004
# Iteration =  distance =  151 0.002509740254495796
# Iteration =  distance =  152 0.0023842532417717166
# Iteration =  distance =  153 0.0022650405796866835
# Iteration =  distance =  154 0.0021517885507051915
# Iteration =  distance =  155 0.002044199123162116
# Iteration =  distance =  156 0.0019419891670082734
# Iteration =  distance =  157 0.0018448897086642546
# Iteration =  distance =  158 0.0017526452232345946
# Iteration =  distance =  159 0.0016650129620785492
# Iteration =  distance =  160 0.0015817623139753323
# Iteration =  distance =  161 0.0015026741982779868
# Iteration =  distance =  162 0.001427540488364798
# Iteration =  distance =  163 0.001356163463952953
# Iteration =  distance =  164 0.0012883552907538842
# Iteration =  distance =  165 0.0012239375262197427
# Iteration =  distance =  166 0.001162740649917282
# Iteration =  distance =  167 0.0011046036174207075
# Iteration =  distance =  168 0.0010493734365581986
# Iteration =  distance =  169 0.0009969047646904983
# Iteration =  distance =  170 0.0009470595264531312
# Iteration =  distance =  171 0.0008997065501432644
# Iteration =  distance =  172 0.0008547212226375223
# Iteration =  distance =  173 0.0008119851615049356
# Iteration =  distance =  174 0.0007713859034197412
# Iteration =  distance =  175 0.0007328166082487542
# Iteration =  distance =  176 0.0006961757778469746
# Iteration =  distance =  177 0.0006613669889503626
# Iteration =  distance =  178 0.0006282986395120815
# Iteration =  distance =  179 0.0005968837075442934
# Iteration =  distance =  180 0.0005670395221670788
# Iteration =  distance =  181 0.0005386875460544616
# Iteration =  distance =  182 0.0005117531687517385
# Iteration =  distance =  183 0.00048616551032409916
# Iteration =  distance =  184 0.00046185723481073637
# Iteration =  distance =  185 0.00043876437305812033
# Iteration =  distance =  186 0.0004168261544066354
# Iteration =  distance =  187 0.0003959848466905669
# Iteration =  distance =  188 0.0003761856043524858
# Iteration =  distance =  189 0.0003573763241462302
# Iteration =  distance =  190 0.00033950750793110274
# Iteration =  distance =  191 0.0003225321325430741
# Iteration =  distance =  192 0.0003064055259187626
# Iteration =  distance =  193 0.0002910852496285088
# Iteration =  distance =  194 0.00027653098715063607
# Iteration =  distance =  195 0.0002627044377874199
# Iteration =  distance =  196 0.0002495692158959173
# Iteration =  distance =  197 0.00023709075510680577
# Iteration =  distance =  198 0.00022523621736070254
# Iteration =  distance =  199 0.00021397440649195687
# Iteration =  distance =  200 0.00020327568616096414
# Iteration =  distance =  201 0.0001931119018507843
# Iteration =  distance =  202 0.00018345630675753455
# Iteration =  distance =  203 0.00017428349141823674
# Iteration =  distance =  204 0.00016556931686295684
# Iteration =  distance =  205 0.00015729085102123008
# Iteration =  distance =  206 0.00014942630846803695
# Iteration =  distance =  207 0.00014195499304037185
# Iteration =  distance =  208 0.00013485724339545868
# Iteration =  distance =  209 0.0001281143812263963
# Iteration =  distance =  210 0.00012170866216365539
# Iteration =  distance =  211 0.00011562322904978828
# Iteration =  distance =  212 0.00010984206760156212
# Iteration =  distance =  213 0.0001043499642179313
# Iteration =  distance =  214 9.913246601911396e-05
# Iteration =  distance =  215 9.417584271886881e-05
# Iteration =  distance =  216 8.946705058576754e-05
# Iteration =  distance =  217 8.499369805292645e-05
# Iteration =  distance =  218 8.074401316093827e-05
# Iteration =  distance =  219 7.670681250715461e-05
# Iteration =  distance =  220 7.287147188606014e-05
# Iteration =  distance =  221 6.922789829388876e-05
# Iteration =  distance =  222 6.576650338274703e-05
# Iteration =  distance =  223 6.247817820792534e-05
# Iteration =  distance =  224 5.935426929681853e-05
# Iteration =  distance =  225 5.6386555840504116e-05
# Iteration =  distance =  226 5.356722805061054e-05
# Iteration =  distance =  227 5.0888866638842956e-05
# Iteration =  distance =  228 4.834442330547972e-05
# Iteration =  distance =  229 4.592720215157442e-05
# Iteration =  distance =  230 4.3630842043285156e-05
# Iteration =  distance =  231 4.144929989990942e-05
# Iteration =  distance =  232 3.937683490562449e-05
# Iteration =  distance =  233 3.740799316176435e-05
# Iteration =  distance =  234 3.553759350438668e-05
# Iteration =  distance =  235 3.3760713847641455e-05
# Iteration =  distance =  236 3.207267815241721e-05
# Iteration =  distance =  237 3.0469044219216812e-05
# Iteration =  distance =  238 2.8945592006834886e-05
# Iteration =  distance =  239 2.74983124057826e-05
# Iteration =  distance =  240 2.612339679330944e-05
# Iteration =  distance =  241 2.4817226957907224e-05
# Iteration =  distance =  242 2.357636560645915e-05
# Iteration =  distance =  243 2.239754732613619e-05
# Iteration =  distance =  244 2.1277669958408296e-05
# Iteration =  distance =  245 2.0213786456224625e-05
# Iteration =  distance =  246 1.9203097139097736e-05
# Iteration =  distance =  247 1.8242942289248276e-05
# Iteration =  distance =  248 1.733079517407532e-05
# Iteration =  distance =  249 1.6464255423898067e-05
# Iteration =  distance =  250 1.5641042651282078e-05
# Iteration =  distance =  251 1.4858990525112858e-05
# Iteration =  distance =  252 1.4116041000988844e-05
# Iteration =  distance =  253 1.3410238949518316e-05
# Iteration =  distance =  254 1.2739726997779144e-05
# Iteration =  distance =  255 1.210274064078476e-05
# Iteration =  distance =  256 1.1497603608745521e-05
# Iteration =  distance =  257 1.0922723433282044e-05
# Iteration =  distance =  258 1.0376587269433912e-05
# Iteration =  distance =  259 9.857757916620358e-06
# Iteration =  distance =  260 9.364870024342054e-06
# Iteration =  distance =  261 8.896626511045724e-06
# Iteration =  distance =  262 8.45179516772987e-06
# Iteration =  distance =  263 8.029205417869889e-06
# Iteration =  distance =  264 7.627745162608335e-06
# Iteration =  distance =  265 7.24635791016226e-06
# Iteration =  distance =  266 6.884040018917403e-06
# Iteration =  distance =  267 6.5398380115766486e-06
# Iteration =  distance =  268 6.212846116682158e-06
# Iteration =  distance =  269 5.902203810137507e-06
# Iteration =  distance =  270 5.607093626736059e-06
# Iteration =  distance =  271 5.326738943267628e-06
# Iteration =  distance =  272 5.060402003209674e-06
# Iteration =  distance =  273 4.807381898785934e-06
# Iteration =  distance =  274 4.5670128088204365e-06
# Iteration =  distance =  275 4.338662165537244e-06
# Iteration =  distance =  276 4.121729062944723e-06
# Iteration =  distance =  277 3.9156426225872565e-06
# Iteration =  distance =  278 3.719860501405492e-06
# Iteration =  distance =  279 3.5338674706508755e-06
# Iteration =  distance =  280 3.3571740942761608e-06
# Iteration =  distance =  281 3.1893153931150664e-06
# Iteration =  distance =  282 3.0298496227487703e-06
# Iteration =  distance =  283 2.8783571508483874e-06
# Iteration =  distance =  284 2.7344392918848826e-06
# Iteration =  distance =  285 2.5977173265800957e-06
# Iteration =  distance =  286 2.4678314503034926e-06
# Iteration =  distance =  287 2.344439877788318e-06
# Iteration =  distance =  288 2.2272178910043294e-06
# Iteration =  distance =  289 2.1158570007173694e-06
# Iteration =  distance =  290 2.010064150681501e-06
# Iteration =  distance =  291 1.9095609360419985e-06
# Iteration =  distance =  292 1.8140828927926123e-06
# Iteration =  distance =  293 1.7233787161785585e-06
# Iteration =  distance =  294 1.6372097775274597e-06
# Iteration =  distance =  295 1.5553492858089157e-06
# Iteration =  distance =  296 1.477581818676299e-06
# Iteration =  distance =  297 1.4037027540325653e-06
# Iteration =  distance =  298 1.333517616330937e-06
# Iteration =  distance =  299 1.2668417070926807e-06
# Iteration =  distance =  300 1.2034996217380467e-06
# Iteration =  distance =  301 1.1433246385195162e-06
# Iteration =  distance =  302 1.0861584058829976e-06
# Iteration =  distance =  303 1.031850487720476e-06
# Iteration =  distance =  304 9.802579654660803e-07
# Iteration =  distance =  305 9.312450686138618e-07
# Iteration =  distance =  306 8.846828194464251e-07
# Iteration =  distance =  307 8.404486919744159e-07
# Iteration =  distance =  308 7.984262566651523e-07
# Iteration =  distance =  309 7.585049530689503e-07
# Iteration =  distance =  310 7.205797061260455e-07
# Iteration =  distance =  311 6.845507130037731e-07
# Iteration =  distance =  312 6.503231730903281e-07
# Iteration =  distance =  313 6.178070179885253e-07
# Iteration =  distance =  314 5.8691666993127e-07
# Iteration =  distance =  315 5.575708286187364e-07
# Iteration =  distance =  316 5.296922864772569e-07
# Iteration =  distance =  317 5.032076728639368e-07
# Iteration =  distance =  318 4.780472977472527e-07
# Iteration =  distance =  319 4.541449243333773e-07
# Iteration =  distance =  320 4.314376838010503e-07
# Iteration =  distance =  321 4.0986580529533967e-07
# Iteration =  distance =  322 3.8937251645165816e-07
# Iteration =  distance =  323 3.6990388707636157e-07
# Iteration =  distance =  324 3.514087012490563e-07
# Iteration =  distance =  325 3.338382583706334e-07
# Iteration =  distance =  326 3.17146344741559e-07
# Iteration =  distance =  327 3.012890203990537e-07
# Iteration =  distance =  328 2.8622457648452837e-07
# Iteration =  distance =  329 2.719133362916182e-07
# Iteration =  distance =  330 2.5831766947703727e-07
# Iteration =  distance =  331 2.4540179310861276e-07
# Iteration =  distance =  332 2.3313170061101118e-07
# Iteration =  distance =  333 2.214751049223196e-07
# Iteration =  distance =  334 2.104013532289173e-07
# Iteration =  distance =  335 1.998812848569287e-07
# Iteration =  distance =  336 1.8988721706136857e-07
# Iteration =  distance =  337 1.803928455501591e-07
# Iteration =  distance =  338 1.713732160624204e-07
# Iteration =  distance =  339 1.628045538382139e-07
# Iteration =  distance =  340 1.5466433467281604e-07
# Iteration =  distance =  341 1.4693111438646156e-07
# Iteration =  distance =  342 1.39584557246053e-07
# Iteration =  distance =  343 1.3260533648917772e-07
# Iteration =  distance =  344 1.2597507748068892e-07
# Iteration =  distance =  345 1.1967631508014165e-07
# Iteration =  distance =  346 1.136925078526474e-07
# Iteration =  distance =  347 1.0800788174947229e-07
# Iteration =  distance =  348 1.0260748695145594e-07
# Iteration =  distance =  349 9.747711260388314e-08
# Iteration =  distance =  350 9.260325839477446e-08
# Iteration =  distance =  351 8.797310613317677e-08
# Iteration =  distance =  352 8.357444869488972e-08
# Iteration =  distance =  353 7.939573265502986e-08
# Iteration =  distance =  354 7.54259446011929e-08
# Iteration =  distance =  355 7.165465376601787e-08
# Iteration =  distance =  356 6.807192676205887e-08
# Iteration =  distance =  357 6.466832758178498e-08
# Iteration =  distance =  358 6.143490338672564e-08
# Iteration =  distance =  359 5.836315608576115e-08
# Iteration =  distance =  360 5.544501391341328e-08
# Iteration =  distance =  361 5.267276037557167e-08
# Iteration =  distance =  362 5.003913372547686e-08
# Iteration =  distance =  363 4.7537170644318394e-08
# Iteration =  distance =  364 4.516030571721785e-08
# Iteration =  distance =  365 4.290230037895526e-08
# Iteration =  distance =  366 4.075718607055023e-08
# Iteration =  distance =  367 3.8719321082680835e-08
# Iteration =  distance =  368 3.678336213397415e-08
# Iteration =  distance =  369 3.494419331673271e-08
# Iteration =  distance =  370 3.319698294035334e-08
# Iteration =  distance =  371 3.153712668790831e-08
# Iteration =  distance =  372 2.996027603785478e-08
# Iteration =  distance =  373 2.846225299890648e-08
# Iteration =  distance =  374 2.703914958601672e-08
# Iteration =  distance =  375 2.5687199922685977e-08
# Iteration =  distance =  376 2.4402837084380735e-08
# Iteration =  distance =  377 2.3182707309388206e-08
# Iteration =  distance =  378 2.2023570522833325e-08
# Iteration =  distance =  379 2.0922385601807036e-08
# Iteration =  distance =  380 1.9876267742802156e-08
# Iteration =  distance =  381 1.8882460040003934e-08
# Iteration =  distance =  382 1.793833348529006e-08
# Iteration =  distance =  383 1.7041415389940084e-08
# Iteration =  distance =  384 1.6189346752071287e-08
# Iteration =  distance =  385 1.5379882256638666e-08
# Iteration =  distance =  386 1.4610876064580225e-08
# Iteration =  distance =  387 1.3880338656235836e-08
# Iteration =  distance =  388 1.3186323144509515e-08
# Iteration =  distance =  389 1.2527010539997718e-08
# Iteration =  distance =  390 1.1900652907570475e-08
# Iteration =  distance =  391 1.1305615998935536e-08
# Iteration =  distance =  392 1.0740336620074231e-08
# Iteration =  distance =  393 1.0203322631241463e-08
# Iteration =  distance =  394 9.69315294696571e-09
# Value function converged after this many iterations: 395

# %% [markdown]
# ## Step 4: Extract decision rules from solution

# %%
'''
------------------------------------------------------------------------
Find consumption and savings policy functions   
------------------------------------------------------------------------
optW  = vector, the optimal choice of w' for each w
optC  = vector, the optimal choice of c for each c
------------------------------------------------------------------------
'''
optW = w_grid[PF] # tomorrow's optimal cake size (savings function)
optC = w_grid - optW # optimal consumption - get consumption through the transition eqn

# %% [markdown]
# ## Visualize output

# %%
# Plot value function 
plt.figure()
# plt.plot(wvec, VF)
plt.scatter(w_grid[1:], VF[1:])
plt.xlabel('Size of Cake')
plt.ylabel('Value Function')
plt.title('Value Function - deterministic cake eating')
plt.show()

# %%
# Plot value function at several iterations
plt.figure()
fig, ax = plt.subplots()
ax.plot(w_grid, Vstore[:,0], label='1st iter')
ax.plot(w_grid, Vstore[:,10], label='0th iter')
ax.plot(w_grid, Vstore[:,20], label='20th iter')
ax.plot(w_grid, Vstore[:,30], label='30th iter')
ax.plot(w_grid, Vstore[:,40], label='40th iter')
ax.plot(w_grid, Vstore[:,VFiter-1], 'k', label='Last iter')
# Now add the legend with some customizations.
legend = ax.legend(loc='lower right', shadow=False)
# Set the fontsize
for label in legend.get_texts():
    label.set_fontsize('large')
for label in legend.get_lines():
    label.set_linewidth(1.5)  # the legend line width
plt.xlabel('Size of Cake')
plt.ylabel('Value Function')
plt.title('Value Function - deterministic cake eating')
plt.show()

# %%
#Plot optimal consumption rule as a function of cake size
plt.figure()
fig, ax = plt.subplots()
ax.plot(w_grid[1:], optC[1:], label='Consumption')
# Now add the legend with some customizations.
legend = ax.legend(loc='upper left', shadow=False)
# Set the fontsize
for label in legend.get_texts():
    label.set_fontsize('large')
for label in legend.get_lines():
    label.set_linewidth(1.5)  # the legend line width
plt.xlabel('Size of Cake')
plt.ylabel('Optimal Consumption')
plt.title('Policy Function, consumption - deterministic cake eating')
plt.show()

# %%
#Plot cake to leave rule as a function of cake size
plt.figure()
fig, ax = plt.subplots()
ax.plot(w_grid[1:], optW[1:], label='Savings')
ax.plot(w_grid[1:], w_grid[1:], '--', label='45 degree line')
# Now add the legend with some customizations.
legend = ax.legend(loc='upper left', shadow=False)
# Set the fontsize
for label in legend.get_texts():
    label.set_fontsize('large')
for label in legend.get_lines():
    label.set_linewidth(1.5)  # the legend line width
plt.xlabel('Size of Cake')
plt.ylabel('Optimal Savings')
plt.title('Policy Function, savings - deterministic cake eating')
plt.show()

# %% [markdown]
# ## Finding approximation errors
#
# It's a little complicated (we need to do the guess and verify method), but we can show that with $\sigma = 1.0$ (i.e., $u(c) = log(c)$), then the policy function is $w' = \beta w$.  Knowing this, we can find the approximation error from our solution method (VFI over a discrete grid).  This errors are found as:

# %%
Wprime_errors = optW - beta * w_grid

# Plot policy function approximation errors
plt.figure()
plt.plot(w_grid[1:], Wprime_errors[1:])
plt.xlabel('Size of Cake')
plt.ylabel('Error')
plt.title('VFI w prime policy function errors')
plt.show()

# %%
C_errors = optC - (1 - beta) * w_grid
# Plot policy function approximation errors
plt.figure()
plt.plot(w_grid[1:], C_errors[1:])
plt.xlabel('Size of Cake')
plt.ylabel('Error')
plt.title('VFI consumption policy function errors')
plt.show()

# %%
# Compute true value function if u(c)=log(c)
B = 1 / (1 - beta)
A = B * np.log(1 - beta) + B * B * beta * np.log(R * beta)
true_VF = A + B * np.log(w_grid)
VF_errors = VF - true_VF
# Plot value function approximation errors
plt.figure()
plt.plot(w_grid[1:], VF_errors[1:])
plt.xlabel('Size of Cake')
plt.ylabel('Error')
plt.title('Value function errors')
plt.show()

# %%
# Plot true and found value functions
plt.figure()
plt.plot(w_grid[1:], VF[1:], label='Approximated VF')
plt.plot(w_grid[1:], true_VF[1:], label='True VF')
plt.xlabel('Size of Cake')
plt.ylabel('Value')
plt.title('Value functions')
plt.legend(loc='lower right')
plt.show()

# %%
import numpy as np
from matplotlib import pyplot as plt

# %%
y = np.arange(-5,6)**2
y
# Out:
# array([25, 16,  9,  4,  1,  0,  1,  4,  9, 16, 25], dtype=int32)

# %%
plt.plot(y)
plt.show()

# %%
plt.show()
